# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/file.csv

# %%
import pandas as pd
file = pd.read_csv("../input/file.csv")
#select the parks of canada only 
file = file[file['Country'].str.strip() == "CANADA"]
print(file.head(5))
#select specified columns only 
modified = file[['ParkName','State','partySize','BookingType','RateType','Equipment']]
#save modified data as file2.csv without index
modified.to_csv("file2.csv", index=False)
modified
# Out:
#           ParkName State  Country  Adult  Child  partySize RateType  \
# 0      Dollar Lake   NS   CANADA       2    NaN          2   Senior
# 1   Thomas Raddall   QC   CANADA       1    NaN          1   Senior
# 3    Amherst Shore   NS   CANADA       2    NaN          2     Full
# 4  Caribou Munroes   NS   CANADA       2    2.0          4     Full
# 5          Salsman   NS   CANADA       2    NaN          2     Full
#
#       BookingType       Equipment BookingStartDate BookingEnddate  Night  \
# 0  CampsitePermit  Less than 20ft       09/21/2016     09/25/2016      4
# 1  CampsitePermit  Less than 30ft       08/01/2016     08/06/2016      5
# 3  CampsitePermit           Tents       09/16/2016     09/18/2016      2
# 4  CampsitePermit  Less than 20ft       08/26/2016     08/28/2016      2
# 5  CampsitePermit  Less than 40ft       07/29/2016     07/31/2016      2
#
#    Permits
# 0        1
# 1        1
# 3        1
# 4        1
# 5        1
#               ParkName State  partySize     BookingType RateType  \
# 0          Dollar Lake   NS           2  CampsitePermit   Senior
# 1       Thomas Raddall   QC           1  CampsitePermit   Senior
# 3        Amherst Shore   NS           2  CampsitePermit     Full
# 4      Caribou Munroes   NS           4  CampsitePermit     Full
# 5              Salsman   NS           2  CampsitePermit     Full
# ...                ...   ...        ...             ...      ...
# 34935   Thomas Raddall   AB           1  CampsitePermit     Full
# 34937     Five Islands   ON           3  CampsitePermit     Full
# 34938      The Islands   NS           2  CampsitePermit     Full
# 34939       Valleyview   NS           2  CampsitePermit     Full
# 34940   Thomas Raddall   NS           1  CampsitePermit   Senior
#
#             Equipment
# 0      Less than 20ft
# 1      Less than 30ft
# 3               Tents
# 4      Less than 20ft
# 5      Less than 40ft
# ...               ...
# 34935     Single Tent
# 34937     Single Tent
# 34938  Less than 20ft
# 34939  Less than 20ft
# 34940     Single Tent
#
# [30754 rows x 6 columns]

# %%
#replace Equipment column data as mention in pdf
modified['Equipment'].replace("Less than 40ft", "LT40ft",inplace = True)
modified['Equipment'].replace("Greater than 40ft", "GT40ft",inplace = True)
modified['Equipment'].replace("Less than 30ft", "LT30ft",inplace = True)
modified['Equipment'].replace("Less than 20ft", "LT20ft",inplace = True)
modified['Equipment'].replace("Single Tent", "ST",inplace = True)
#save modified data as file3.csv
modified.to_csv("file3.csv", index=False)
modified
# Out:
#               ParkName State  partySize     BookingType RateType Equipment
# 0          Dollar Lake   NS           2  CampsitePermit   Senior    LT20ft
# 1       Thomas Raddall   QC           1  CampsitePermit   Senior    LT30ft
# 3        Amherst Shore   NS           2  CampsitePermit     Full     Tents
# 4      Caribou Munroes   NS           4  CampsitePermit     Full    LT20ft
# 5              Salsman   NS           2  CampsitePermit     Full    LT40ft
# ...                ...   ...        ...             ...      ...       ...
# 34935   Thomas Raddall   AB           1  CampsitePermit     Full        ST
# 34937     Five Islands   ON           3  CampsitePermit     Full        ST
# 34938      The Islands   NS           2  CampsitePermit     Full    LT20ft
# 34939       Valleyview   NS           2  CampsitePermit     Full    LT20ft
# 34940   Thomas Raddall   NS           1  CampsitePermit   Senior        ST
#
# [30754 rows x 6 columns]

# %%
#filter parks of state NS only 
temp = modified[modified['State'].str.strip() == "NS"]
#sort the data based on partysize
temp = temp.sort_values(by = "partySize", ascending=False)
# remove duplicate parkname entires
temp.drop_duplicates(subset ="ParkName" ,inplace=True)
print(temp)
#save modified data as file4.csv
temp.to_csv("file4.csv", index=False)
# Out:
#               ParkName State  partySize        BookingType RateType Equipment
# 26252    Graves Island   NS          35     CampsitePermit     Full     Tents
# 32597   Cape Chignecto   NS          14  BackcountryPermit     Full        ST
# 17733   Ellenwood Lake   NS          12     CampsitePermit     Full    LT30ft
# 26126      Dollar Lake   NS          11     CampsitePermit     Full        ST
# 3696        Valleyview   NS          11     CampsitePermit     Full        ST
# 30353         Blomidon   NS          10     CampsitePermit     Full     Tents
# 3823   Caribou Munroes   NS           9     CampsitePermit     Full     Tents
# 21259       Mira River   NS           9     CampsitePermit     Full        ST
# 4746           Battery   NS           9     CampsitePermit     Full     Tents
# 32332   Thomas Raddall   NS           8     CampsitePermit     Full        ST
# 13839    Rissers Beach   NS           8     CampsitePermit     Full     Tents
# 15673           Laurie   NS           8     CampsitePermit     Full     Tents
# 4578      Five Islands   NS           7     CampsitePermit     Full     Tents
# 28475     Porters Lake   NS           7     CampsitePermit     Full        ST
# 16098          Salsman   NS           6     CampsitePermit     Full     Tents
# 16696          Smileys   NS           6     CampsitePermit     Full     Tents
# 16761      The Islands   NS           6     CampsitePermit     Full    LT20ft
# 16235    Amherst Shore   NS           6     CampsitePermit     Full     Tents
# 30356      Whycocomagh   NS           6     CampsitePermit     Full    LT30ft
# 18162         Boylston   NS           6     CampsitePermit     Full     Tents
